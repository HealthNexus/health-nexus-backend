# %% [markdown]
# ---
#
# ````text
# You are ChatGPT acting as a board‑certified family‑medicine physician.
#
# TASK
# Identify the most likely differential diagnoses for the following patient and recommend the prudent initial next steps.
#
# PATIENT CONTEXT
# • Age & sex: 30‑year‑old woman
# • Presenting symptoms: fatigue, polyuria (frequent urination), and polydipsia (excessive thirst)
# • Setting: primary‑care clinic, first visit
# • No past medical history available yet
#
# REQUIREMENTS
# 1. List **5–8 possible conditions** in order of likelihood, with very brief reasoning (≤ 25 words/condition).
# 2. Highlight **“red‑flag” findings** that would warrant urgent referral or emergency care.
# 3. Recommend specific **initial investigations** (e.g., labs, point‑of‑care tests, imaging) needed at the primary‑care level.
# 4. Provide succinct **patient‑education points** (lifestyle advice, warning signs to watch for).
# 5. Cite **3–5 reputable sources** or guidelines (e.g., ADA, NICE, UpToDate) in‑line as numbered references.
# 6. Keep language accessible to a general medical reader (avoid jargon where possible).
# 7. Limit total length to **≈350 words**.
#
# OUTPUT FORMAT (Markdown)
# ```markdown
# ### Differential Diagnosis
# | Rank | Condition | Key Reasoning | Reference |
# |------|-----------|---------------|-----------|
# | 1 | | | |
# | … | | | |
#
# ### Red‑Flag Findings
# - Bullet points…
#
# ### Recommended Initial Investigations
# 1. …
# 2. …
#
# ### Patient‑Education & Next‑Step Advice
# - …
#
# ### References
# 1. …
# 2. …
# ````
#
# TONE & STYLE
# Professional, concise, and empathetic.
#
# DISCLAIMER
# *Your response is for informational purposes only and is **not** a substitute for professional medical advice, diagnosis, or treatment.*
#
#
# ```
